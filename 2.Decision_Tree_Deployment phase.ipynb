# %%
#Load the best performed model:
import pickle

loaded_model=pickle.load(open("Final_Regression_Decision_Tree.sav",'rb'))
result=loaded_model.predict([[345,567,895,0,1]])
# Out:
# C:\Anaconda3\Lib\site-packages\sklearn\utils\validation.py:2749: UserWarning: X does not have valid feature names, but DecisionTreeRegressor was fitted with feature names
#   warnings.warn(

# %%
result
# Out:
# array([35673.41])
