# %%
import pickle

# %%
sc=pickle.load(open("preprocessed_scaler.sav",'rb'))

# %%
preinput=sc.transform([[487,398,93284,1,0]])
# Out:
# C:\Anaconda3\Lib\site-packages\sklearn\utils\validation.py:2749: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(

# %%
loaded_model=pickle.load(open("preprocessed_SVMR.sav",'rb'))

# %%
result=loaded_model.predict(preinput)

# %%
result
# Out:
# array([41706.96374221])
