# %%
#Load the model:
import pickle

loaded_model = pickle.load(open("finalized_Mul_linear.sav",'rb'))

# %%
result=loaded_model.predict([[456,789,456,1,0]])
# Out:
# C:\Anaconda3\Lib\site-packages\sklearn\utils\validation.py:2749: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(

# %%
result
# Out:
# array([[43265.49108113]])
